# %% [markdown]
# ## Initialise libraries

# %%
pip install bertopic

# %%
import pandas as pd
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords = stopwords.words('french')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Import media dataset

# %%
df = pd.read_csv("FULL_with_titles.zip", compression="zip")

# %% [markdown]
# # Topic Modelling Colab – Calculate, explore, save

# %% [markdown]
# ## Define documents, conduct and save topic modelling

# %%
df["normalized_url_phrases"] = df["normalized_url_phrases"].astype(str)
documents = list(df["normalized_url_phrases"].unique())

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
document_vectors = model.encode(documents,show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/7096 [00:00<?, ?it/s]

# %%
vectorizer = CountVectorizer(stop_words=stopwords)
umap_model = UMAP(n_neighbors=10, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
hdbscan_model = HDBSCAN(min_cluster_size=20, min_samples=2, metric='euclidean', cluster_selection_method='eom')

topic_model = BERTopic(
    language="multilingual",
    embedding_model=model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer,
    verbose=True
).fit(documents, document_vectors)
# Out:
# 2024-03-04 09:54:40,094 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-03-04 10:02:01,046 - BERTopic - Dimensionality - Completed ✓
# 2024-03-04 10:02:01,056 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-03-04 10:02:20,703 - BERTopic - Cluster - Completed ✓
# 2024-03-04 10:02:20,816 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-03-04 10:02:28,597 - BERTopic - Representation - Completed ✓

# %%
topic_model.save("model 1 - headlines")
# Out:
# 2024-03-04 10:02:39,447 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %% [markdown]
# ## Visualize barchart first 100 topics

# %%
topic_model.visualize_barchart(top_n_topics=100)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="75f32ee5-5c58-491a-9a86-426608acc3a0" class="plotly-graph-div" style="height:6250px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75f32ee5-5c58-491a-9a86-426608acc3a0")) {                    Plotly.newPlot(                        "75f32ee5-5c58-491a-9a86-426608acc3a0",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0022189264859522233,0.002283642529471998,0.0023111777881232513,0.002647111090282146,0.002802001518937501],"y":["entreprises  ","boulot  ","3232  ","bonheur  ","4497916  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007020083664814534,0.007958316349667868,0.009977071966590553,0.010428287407689122,0.034329265365560996],"y":["libye  ","accueil  ","mediterranee  ","migrant  ","migrants  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.010260406249458393,0.012137665122915349,0.012433677684038913,0.015184895629571116,0.019656211912912783],"y":["policier  ","billet  ","politiques  ","policiers  ","politique  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.00261781921351194,0.002761236776159955,0.003059004312993879,0.0030914062097257347,0.003169599369080431],"y":["20190315  ","20190623  ","daesh  ","20190626  ","20190131  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.004123532878272542,0.0044203822006281795,0.004723324264015538,0.006291563845146967,0.019369475289315093],"y":["croient  ","pensent  ","soutiennent  ","sondage  ","francais  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.00957713592540392,0.013061744284189518,0.014955074071776008,0.042687249116472724,0.04611177680880697],"y":["hillary  ","4853715  ","clinton  ","donald  ","trump  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.011612743632800312,0.013975704616598781,0.027951950362908297,0.02873590934993816,0.03348981842001603],"y":["conjugales  ","violente  ","violence  ","policieres  ","violences  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.003652189803283128,0.0037383974180969794,0.004954813777033352,0.015280344989193274,0.03712191551332937],"y":["popularite  ","coiffeur  ","2013  ","francois  ","hollande  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.007004619255262789,0.007995491410388971,0.03359200978272126,0.03420237124333075,0.04478765093181571],"y":["reporters  ","dgsi  ","journalisme  ","journaliste  ","journalistes  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.005808197505495787,0.0058152384693989576,0.01039256569998762,0.03564014233838945,0.05135889317973843],"y":["fn  ","marineland  ","assistants  ","pen  ","marine  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.008720012972405756,0.023930843946157212,0.03146443463866938,0.03533316783373059,0.04932747572205619],"y":["mediatiques  ","mediatique  ","media  ","mediapart  ","medias  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.005156487157509965,0.0058762801498757,0.006744127620636469,0.018443618156906795,0.03593449328065222],"y":["5070021  ","3121  ","4854003  ","francois  ","fillon  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.007192234965429932,0.01498412806394837,0.018078992866376143,0.023695801358718013,0.03597004390884416],"y":["assemblee  ","lrem  ","deputee  ","depute  ","deputes  "]," ...

# %% [markdown]
# ## Assign topics back to df_topics

# %%
df_topics = pd.DataFrame()
df_topics["normalized_url_phrases"] = documents
df_topics["topic"] = topic_model.topics_
df_topics.to_csv("FR_headlines_topics.csv", index = False)
df_topics.head()
# Out:
#                               normalized_url_phrases  topic
# 0  rennes ils tendent un guet apens aux pompiers ...     -1
# 1  on devrait faire payer aux francais les appels...     -1
# 2  sciences po supprime son concours d entree 201...    144
# 3  ils lancent une petition le retour des veritab...    264
# 4  un label pour les commercants secouristes de l...     -1

# %%
print(f'The topic model yielded a total of {max(df_topics.topic)} topics derived from {len(documents)} unique documents. The topic model table looks like this:')
print("")
topic_info_df = topic_model.get_topic_info()
topic_info_df
# Out:
# The topic model yielded a total of 1803 topics derived from 227066 unique documents. The topic model table looks like this:
#       Topic  Count                                            Name  \
# 0        -1  62184                -1_sarkozy_video_macron_emmanuel
# 1         0   1640                   0_4497916_bonheur_3232_boulot
# 2         1   1254         1_migrants_migrant_mediterranee_accueil
# 3         2   1110         2_politique_policiers_politiques_billet
# 4         3   1016              3_20190131_20190626_daesh_20190623
# ...     ...    ...                                             ...
# 1800   1799     20  1799_burundi_nkurunziza_nshimirimana_bujumbura
# 1801   1800     20                      1800_guerrab_jid_el_casque
# 1802   1801     20      1801_enfarine_destabiliser_erigeait_858710
# 1803   1802     20      1802_mannequin_mannequins_negzzia_23347424
# 1804   1803     20             1803_jauni_hissee_autruches_moondog
#
#                                          Representation  \
# 0     [sarkozy, video, macron, emmanuel, femmes, fem...
# 1     [4497916, bonheur, 3232, boulot, entreprises, ...
# 2     [migrants, migrant, mediterranee, accueil, lib...
# 3     [politique, policiers, politiques, billet, pol...
# 4     [20190131, 20190626, daesh, 20190623, 20190315...
# ...                                                 ...
# 1800  [burundi, nkurunziza, nshimirimana, bujumbura,...
# 1801  [guerrab, jid, el, casque, mjid, membre, deput...
# 1802  [enfarine, destabiliser, erigeait, 858710, 831...
# 1803  [mannequin, mannequins, negzzia, 23347424, mai...
# 1804  [jauni, hissee, autruches, moondog, farrachi, ...
#
#                                     Representative_Docs
# 0     [et apres quoi  41 des francais affirment qu i...
# 1     [vous etes grosse et moche soyez seulement moc...
# 2     [libye sahara plus de migrants meurent terre q...
# 3     [le billet politique du jeudi 15 novembre 2018...
# 4     [2440711 20190131 drome salarie amazon licenci...
# ...                                                 ...
# 1800  [20180905 burundi commission enquete onu pierr...
# 1801  [le depute m jid el guerrab decide de ne pas d...
# 1802  [video en deplacement a romilly sur seine fran...
# 1803  [negzzia mannequin en iran demandeuse d asile ...
# 1804  [aphatie a t il jauni pendant les vacances, mo...
#
# [1805 rows x 5 columns]

# %% [markdown]
# ## Explore topics to look for those related to climate and immigration – top 5

# %%
def find_similar_topics(word):
  similar_topics, similarity = topic_model.find_topics(word, top_n=5)
  print(f"The top 5 topics relating to {word} are: ")
  print("")

  for topic in similar_topics:
    print("Topic number:", topic)
    print("Representative document:", list(topic_info_df[topic_info_df.Topic == topic]["Representative_Docs"]))
    print("Representative words:", list(topic_info_df[topic_info_df.Topic == topic]["Representation"]))
    print("----------------------")

# %%
find_similar_topics("immigration")
# Out:
# The top 5 topics relating to immigration are:
#
# Topic number: 348
# Representative document: [['loi asile et immigration une operation gilets de sauvetage devant le senat mardi', 'loi asile et immigration le fn et en marche main dans la main a l assemblee', 'trois deputes lrem menaces apres avoir refuse de voter la loi asile immigration']]
# Representative words: [['immigration', 'asile', 'texte', 'lhemicycle', 'loi', '1654200', '23662877', 'dhapsatou', 'mexique', 'exclue']]
# ----------------------
# Topic number: 1280
# Representative document: [['immigration affaires europe une campagne presidentielle truffee d intox 5115607 4355770', 'la singularite francaise en matiere d immigration est aussi le fruit de l imperfection juridique europeenne didier leschi', '1214335 reseaux sociaux nouveaux visages comment le vlaams belang parti anti immigration a seduit la jeunesse flamande']]
# Representative words: [['immigration', 'mecanisme', 'intox', '5361784', '5429523', '5435717', '5115607', '5243206', '4788517', '4518397']]
# ----------------------
# Topic number: 984
# Representative document: [['31001 20160308ARTFIG00241 immigration cette loi votee en catimini qui elargit le droit du sol', '31002 20180831ARTFIG00306 renaud girard l immigration de masse est un scenario perdant perdant', '01002 20180306ARTFIG00280 1983 l annee o l immigration s installa dans le debat public8230et o le fn perca']]
# Representative words: [['immigration', '31001', 'asile', 'goldnadel', '31002', 'catimini', 'perdant', '20180914artfig00347', '20180903artfig00215', '20180911artfig00272']]
# ----------------------
# Topic number: 1326
# Representative document: [['matteo salvini refuse aide ue', 'italie matteo salvini migrants', 'italie matteo salvini migrants 2']]
# Representative words: [['matteo', 'salvini', 'italie', 'criminalise', 'saviano', 'roberto', 'migrants', 'debarquer', '1172436', 'pettorino']]
# ----------------------
# Topic number: 1022
# Representative document: [['1190529 lalgerie accelere les expulsions de migrants 5500 subsahariens reconduits a la frontiere', '31003 20150910ARTFIG00344 on criminalise la moindre interrogation sur les migrants', '31003 20150910ARTFIG00382 michel onfray on criminalise la moindre interrogation sur les migrants']]
# Representative words: [['expulsions', 'migrants', 'militants', 'interrogation', 'criminalise', 'moindre', 'xenophobie', '868443', '5492838', '647666']]
# ----------------------

# %% [markdown]
# # Systematic quantitative topics analysis through similarity function – top 20 topics per word

# %%
immigration = ['immigration', 'immigre', 'migrant', 'immigrant', 'migration',
               'refugie', 'asile', 'accueil', 'sauvetage']
climate =["climat", "changement climatique", "climatique", "environment", "environnement",
          "durable", "soutenable", "ecologique", "ecolo",
          "pollution", "charbon", "petrole", "gaz"]

# %%
df_topics_characteristics = pd.DataFrame(columns= ['topic_number','debate','similar_word'])

for word in immigration:
    similar_topics, similarity = topic_model.find_topics(word, top_n=20)

    for topic in similar_topics:
        temp_dic = {'topic_number' : [topic],
                    'debate' : ['immigration'],
                    'similar_word' : [word]}
        temp_df = pd.DataFrame(temp_dic, columns= ['topic_number','debate','similar_word'])
        df_topics_characteristics = pd.concat([df_topics_characteristics,temp_df])

for word in climate:
    similar_topics, similarity = topic_model.find_topics(word, top_n=20)

    for topic in similar_topics:
        temp_dic = {'topic_number' : [topic],
                    'debate' : ['climate'],
                    'similar_word' : [word]}
        temp_df = pd.DataFrame(temp_dic, columns= ['topic_number','debate','similar_word'])
        df_topics_characteristics = pd.concat([df_topics_characteristics,temp_df])

# %%
df_topics_characteristics.drop_duplicates(inplace=True)
df_topics_characteristics.reset_index(inplace=True, drop=True)
df_topics_characteristics.to_csv('FR_IMM_CLIM_topics_headlines.csv', index=False)

# %%
df_topics = pd.DataFrame()
df_topics["normalized_url_phrases"] = documents
df_topics["topic"] = topic_model.topics_
df_topics.to_csv("FR_ALL_topics_headlines.csv", index = False)
df_topics.head()
# Out:
#                               normalized_url_phrases  topic
# 0  rennes ils tendent un guet apens aux pompiers ...     -1
# 1  on devrait faire payer aux francais les appels...     -1
# 2  sciences po supprime son concours d entree 201...    144
# 3  ils lancent une petition le retour des veritab...    264
# 4  un label pour les commercants secouristes de l...     -1

# %%
topic_info_df = topic_model.get_topic_info()
topic_info_df.to_csv('FR_headlines_topics_INFO.csv', index = False)
topic_info_df.head()
# Out:
#    Topic  Count                                     Name  \
# 0     -1  62184         -1_sarkozy_video_macron_emmanuel
# 1      0   1640            0_4497916_bonheur_3232_boulot
# 2      1   1254  1_migrants_migrant_mediterranee_accueil
# 3      2   1110  2_politique_policiers_politiques_billet
# 4      3   1016       3_20190131_20190626_daesh_20190623
#
#                                       Representation  \
# 0  [sarkozy, video, macron, emmanuel, femmes, fem...
# 1  [4497916, bonheur, 3232, boulot, entreprises, ...
# 2  [migrants, migrant, mediterranee, accueil, lib...
# 3  [politique, policiers, politiques, billet, pol...
# 4  [20190131, 20190626, daesh, 20190623, 20190315...
#
#                                  Representative_Docs
# 0  [et apres quoi  41 des francais affirment qu i...
# 1  [vous etes grosse et moche soyez seulement moc...
# 2  [libye sahara plus de migrants meurent terre q...
# 3  [le billet politique du jeudi 15 novembre 2018...
# 4  [2440711 20190131 drome salarie amazon licenci...
